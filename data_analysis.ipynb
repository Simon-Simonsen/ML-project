# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/claims_train.csv')

# %%
claim_counts = df['ClaimNb'].value_counts().sort_index()
plt.bar(claim_counts.index, claim_counts.values)
plt.title('Class distribution of claims')
# Out:
# Text(0.5, 1.0, 'Class distribution of claims')

# %%
df = df.drop('IDpol', axis=1)

# %%
df['VehGas'].value_counts()
# Out:
# VehGas
# Regular    276723
# Diesel     265687
# Name: count, dtype: int64

# %%
df['ClaimNb'].value_counts()
# Out:
# ClaimNb
# 0     515199
# 1      25718
# 2       1416
# 3         67
# 4          4
# 11         2
# 5          2
# 6          1
# 9          1
# Name: count, dtype: int64

# %%
sns.boxplot(x='ClaimNb', y='DrivAge', data=df)
plt.title('Exposure vs. Claim Number')
plt.show()

# %%
mask = (df['Exposure'] > 1)
df[mask]
# Out:
#         ClaimNb  Exposure Area  VehPower  VehAge  DrivAge  BonusMalus  \
# 272           0      1.03    D         6       4       51          50
# 1298          0      1.01    C        15       0       44          50
# 1767          0      1.06    B         7       1       66          50
# 1990          0      1.01    C         6       8       43          91
# 2209          0      1.03    D         5       3       25          76
# ...         ...       ...  ...       ...     ...      ...         ...
# 536377        0      1.22    D         5       3       40          64
# 536528        0      1.03    C        10      13       64          54
# 536884        0      1.18    D         7      14       36          51
# 541133        0      1.15    E         6       2       42          50
# 542091        0      1.02    E         6      12       61          50
#
#        VehBrand   VehGas  Density Region
# 272          B2   Diesel     1408    R73
# 1298        B11  Regular      162    R93
# ...

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='ClaimNb', y='Region')
# Out:
# <Axes: xlabel='ClaimNb', ylabel='Region'>

# %%
df['ClaimNb'].value_counts()
# Out:
# ClaimNb
# 0     515199
# 1      25718
# 2       1416
# 3         67
# 4          4
# 11         2
# 5          2
# 6          1
# 9          1
# Name: count, dtype: int64

# %%
sns.scatterplot(df, x='BonusMalus', y='DrivAge')
# Out:
# <Axes: xlabel='BonusMalus', ylabel='DrivAge'>
