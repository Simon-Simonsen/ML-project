# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/claims_train.csv")

# %%
df["Area"] = pd.Categorical(df["Area"], categories=sorted(df["Area"].unique()), ordered=True)

# %%
list(df.columns)
# Out:
# ['IDpol',
#  'ClaimNb',
#  'Exposure',
#  'Area',
#  'VehPower',
#  'VehAge',
#  'DrivAge',
#  'BonusMalus',
#  'VehBrand',
#  'VehGas',
#  'Density',
#  'Region']

# %%
plt.scatter(df["Area"], df["Density"])
